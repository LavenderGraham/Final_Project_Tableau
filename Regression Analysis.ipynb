# %% [markdown]
# ## Setting directory and loading packages

# %%
import pandas as pd
import os # use this to access your environment variables
import numpy as np
import statsmodels.api as sm
# For matplotlib
import matplotlib.pyplot as plt
# For seaborn
import seaborn as sns

# %%
os.chdir("C:/Users/Laven/Documents/Data_Analysis/Capstone_Project/")

# %% [markdown]
# ## Loading Data

# %%
bars_and_restaurants_df_no_duplicates_utf8 = pd.read_csv('bars_and_restaurants_df_no_duplicates_utf8.csv')

# %%
bars_in_montreal_collected_unique_utf8 = pd.read_csv('bars_in_montreal_collected_unique_utf8.csv')

# %%
restaurants_in_montreal_collected_unique_utf8 = pd.read_csv('restaurants_in_montreal_collected_unique_utf8.csv')

# %%
complete_citybikes_df = pd.read_csv('complete_citybikes_df.csv')

# %%
montreal_subway_df = pd.read_csv('montreal_subway_stations.csv')

# %%
montreal_light_rail = pd.read_csv('montreal_light_rail.csv')

# %%
montreal_transport_stations = pd.read_csv('montreal_transport_stations.csv')

# %% [markdown]
# ## Defining Functions To Calculate Distance

# %%
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    r = 6371 # Radius of earth in kilometers
    return c * r

# %%
def find_closest_points(list1, list2):
    closest_points = []
    for lat1, lon1 in list1:
        min_distance = float('inf')
        closest_point = None
        for lat2, lon2 in list2:
            distance = haversine(lon1, lat1, lon2, lat2)
            if distance < min_distance:
                min_distance = distance
                closest_point = (lat2, lon2)
        closest_points.append(((lat1, lon1), closest_point, min_distance))
    return closest_points

# %%
def count_nearby_stations(establishment_coords, station_coords, max_distance = 1):
    # This will hold the count of nearby stations for each establishment
    nearby_stations_count = []
    
    for est in establishment_coords:
        count = 0
        for station in station_coords:
            distance = haversine(est[1], est[0], station[1], station[0])
            if distance <= max_distance:
                count += 1
        nearby_stations_count.append(count)
        
    return nearby_stations_count

# %% [markdown]
# ## Getting My Lists Of Coordinate Tuples

# %%
establishments_coords = list(zip(bars_and_restaurants_df_no_duplicates_utf8['Latitude'], bars_and_restaurants_df_no_duplicates_utf8['Longitude']))

# %%
bars_coords = list(zip(bars_in_montreal_collected_unique_utf8['Latitude'], bars_in_montreal_collected_unique_utf8['Longitude']))

# %%
restaurants_coords = list(zip(restaurants_in_montreal_collected_unique_utf8['Latitude'], restaurants_in_montreal_collected_unique_utf8['Longitude']))

# %%
citybikes_coords = list(zip(complete_citybikes_df['Latitude'], complete_citybikes_df['Longitude']))

# %%
subway_coords = list(zip(montreal_subway_df['Latitude'], montreal_subway_df['Longitude']))

# %%
light_rail_coords = list(zip(montreal_light_rail['Latitude'], montreal_light_rail['Longitude']))

# %%
transport_station_coords = list(zip(montreal_transport_stations['Latitude'], montreal_transport_stations['Longitude']))

# %% [markdown]
# ## Adding Transit Counts

# %%
bars_and_restaurants_df_no_duplicates_utf8['Nearby_CityBikes_Stations'] = count_nearby_stations(establishments_coords, citybikes_coords, 1)

# %%
bars_and_restaurants_df_no_duplicates_utf8['Nearby_Subway_Stations'] = count_nearby_stations(establishments_coords, subway_coords, 1)

# %%
bars_and_restaurants_df_no_duplicates_utf8['Nearby_Light_Rail_Stations'] = count_nearby_stations(establishments_coords, light_rail_coords, 1)

# %%
bars_and_restaurants_mv_reg = bars_and_restaurants_df_no_duplicates_utf8

# %%
bars_and_restaurants_mv_reg['Nearby_Stations'] = count_nearby_stations(establishments_coords, transport_station_coords, 1)

# %%
bars_and_restaurants_mv_reg.to_csv('bars_and_restaurants_mv_reg')

# %%
bars_and_restaurants_mv_reg = pd.read_csv('bars_and_restaurants_mv_reg')

# %%
bars_and_restaurants_mv_reg.head(50)
# Out:
#     Unnamed: 0                                      Name  \
# 0            0                               Pub St-Paul
# 1            1                               Piranha Bar
# 2            2                             Patrick's Pub
# 3            3                     MVP Resto-Bar Sportif
# 4            4                         Pub John Michaels
# 5            5         Peel Pub - Sports Bar/Bar Sportif
# 6            6                                 Bar Macao
# 7            7                              BreWskey Pub
# 8            8                             Bar Tipsy Cow
# 9            9  LE VIEUX/ THE OLD DUBLIN PUB & RESTURANT
# 10          10                              McLean's Pub
# 11          11                        Pub Wolf & Workman
# 12          12                                 Normandie
# 13          13                    Bar Bifteck St-Laurent
# 14          14               Ye Olde Orchard Pub & Grill
# 15          15                                      NYKS
# 16          16                                Bar George
# 17          17  Bartizen - Salle d'événement & Bar Privé
# 18          18                              Bar L'Barouf
# 19          19                 Sir Winston Churchill Pub
# 20          20                              Pub Victoria
# 21          21                                   Le Date
# 22          22                               Bar MINĒRAL
# 23          23                              Bar Dominion
# 24          24                                 Point Bar
# 25          25                        Flâneur Bar Lounge
# 26          26                                 Alice Bar
# 27          27                                   La Cage
# 28          28                       La Distillerie no.1
# 29          29                         Ginkgo Café & Bar
# 30          30                                Bar Renard
# 31          31                              Philemon Bar
# 32          32                          Pub Saint Pierre
# 33          33                      Monsieur café & vins
# 34          34                            Taverne Midway
# 35          35                              Le P'tit Bar
# 36          36                           PointBar Lounge
# 37          37                         Saloon Bistro Bar
# 38          38                                 Bar Furco
# 39          39                              The Coldroom
# 40          40                            El Pequeño Bar
# 41          41                     Bar Le Mal Nécessaire
# 42          42                                   Modavie
# 43          43         Bootlegger cocktail bar & cuisine
# 44          44                               Bar Exotica
# 45          45       Resto-Bar-Café-Breakfast LA BARAQUE
# 46          46                       MajesThé Bistro Bar
# 47          47                           Le Cathcart bar
# 48          48                     BAR St Laurent Frappé
# 49          49                          Bar Pamplemousse
#
#                                               Address   Latitude  Longitude  \
# 0          124 Rue Saint-Paul E, Montréal, QC H2Y 1G6  45.506944 -73.552500
# 1   680 Saint-Catherine St W, Montreal, Quebec H3B...  45.502852 -73.569942
# 2       1707 Saint Denis St, Montreal, Quebec H2X 3K4  45.515570 -73.564079
# 3     200 St Catherine St E, Montreal, Quebec H2X 1L1  45.511730 -73.561981
# 4       458 Pl. Jacques-Cartier, Montréal, QC H2Y 3Z2  45.508011 -73.553953
# 5              1196 Peel St, Montreal, Quebec H3B 2T6  45.499403 -73.571943
# 6      1057 St Laurent Blvd, Montreal, Quebec H2Z 1J6  45.508327 -73.560176
# 7          380 Rue Saint-Paul E, Montréal, QC H2Y 1H3  45.509398 -73.551386
# 8         3575 Av du Parc #4110, Montréal, QC H2X 3P9  45.510275 -73.575045
# 9              636 Rue Cathcart, Montréal, QC H3B 1L9  45.503008 -73.568646
# 10             1210 Peel St, Montreal, Quebec H3B 2T6  45.499530 -73.572134
# 11      139 Saint-Paul St W, Montreal, Quebec H2Y 1Z5  45.503730 -73.554861
# 12             1295 R. Atateken, Montréal, QC H2L 3K9  45.517301 -73.556479
# 13     3702 St Laurent Blvd, Montreal, Quebec H2X 2V4  45.514590 -73.574364
# 14    20 Prince Arthur St W, Montreal, Quebec H2X 1S3  45.513500 -73.572720
# 15           1250 Rue de Bleury, Montréal, QC H3B 2W4  45.506032 -73.566683
# 16  Le Mount Stephen, 1440 Drummond St, Montreal, ...  45.499044 -73.575778
# 17   901 Rue du Square-Victoria, Montréal, QC H2Z 1R1  45.502078 -73.562166
# 18      4171 Saint Denis St, Montreal, Quebec H2W 2M3  45.521809 -73.577784
# 19         1455 Crescent St, Montreal, Quebec H3G 2B2  45.497911 -73.576891
# 20      698 Notre-Dame St W, Montreal, Quebec H3C 1J2  45.500004 -73.560042
# 21   1218 St Catherine St E, Montreal, Quebec H2L 2G9  45.518565 -73.555889
# 22             1641 R. Atateken, Montréal, QC H2L 3L4  45.518798 -73.559708
# 23         1243 Metcalfe St, Montreal, Quebec H3B 2V5  45.500611 -73.571538
# 24      2017 Saint Denis St, Montreal, Quebec H2X 3K8  45.516216 -73.565669
# 25        2050 Mansfield St, Montreal, Quebec H3A 1Y9  45.502519 -73.574411
# 26     1050 Sherbrooke St W, Montreal, Quebec H3A 2R6  45.502066 -73.576016
# 27  150 Rue Sainte-Catherine local 201C, Montréal,...  45.507652 -73.565356
# 28         300 Ontario St E, Montreal, Quebec H2X 1H6  45.514810 -73.565424
# 29  UQAM Pavillon J.-A.-DeSève, 308 rue Ste-Cather...  45.512692 -73.560853
# 30   1272 St Catherine St E, Montreal, Quebec H2L 2H2  45.519037 -73.555496
# 31      111 Saint-Paul St W, Montreal, Quebec H2Y 1Z5  45.504058 -73.554741
# 32         410 Rue Saint-Pierre, Montréal, QC H2Y 1Y3  45.501363 -73.556621
# 33           1102 Rue de Bleury, Montréal, QC H2Z 1N4  45.504696 -73.563817
# 34     1219 St Laurent Blvd, Montreal, Quebec H2X 2S6  45.509740 -73.563263
# 35      3451 Saint Denis St, Montreal, Quebec H2X 3L1  45.517522 -73.568365
# 36      1735 Saint Denis St, Montreal, Quebec H2X 3K4  45.515739 -73.564428
# 37   1333 St Catherine St E, Montreal, Quebec H2L 2H4  45.519898 -73.555104
# 38             425 Mayor St, Montreal, Quebec H3A 1N9  45.505968 -73.569092
# 39             R. Saint-Vincent, Montréal, QC H2Y 1G8  45.507184 -73.553117
# 40        401a R. Saint-Vincent, Montréal, QC H2Y 3A4  45.507122 -73.553145
# 41    1106B St Laurent Blvd, Montreal, Quebec H2Z 1J5  45.508523 -73.561196
# 42        1 Saint-Paul St W, Montreal, Quebec H2Y 1Y6  45.505465 -73.553964
# 43  3481 St Laurent Blvd 2eme Etage, Montreal, Que...  45.513194 -73.570679
# 44         417 Rue Saint-Pierre, Montréal, QC H2Y 2M4  45.501522 -73.556726
# 45         401 R. Saint-Vincent, Montréal, QC H2Y 3A4  45.507079 -73.552991
# 46    2077 Blvd Robert-Bourassa, Montréal, QC H3A 2M3  45.504827 -73.572765
# 47  1 Pl. Monseigneur Charbonneau, Montreal, Quebe...  45.502017 -73.568186
# 48     3900 St Laurent Blvd, Montreal, Quebec H2W 1Y2  45.516249 -73.578170
# 49     1579 St Laurent Blvd, Montreal, Quebec H2X 2S9  45.510883 -73.565665
#
#     Rating  Price Level Geohash Type  Nearby_CityBikes_Stations  \
# 0      3.9          2.0   f25dy  Bar                         15
# 1      4.1          1.0   f25dv  Bar                         32
# 2      4.2          2.0   f25dy  Bar                         17
# 3      3.8          2.0   f25dy  Bar                         26
# 4      4.0          2.0   f25dy  Bar                         18
# 5      3.8          1.0   f25dv  Bar                         28
# 6      3.5          1.0   f25dy  Bar                         31
# 7      4.5          2.0   f25dy  Bar                         12
# 8      3.9          NaN   f25dv  Bar                         18
# 9      4.0          2.0   f25dv  Bar                         32
# 10     4.2          2.0   f25dv  Bar                         28
# 11     4.6          2.0   f25dy  Bar                         19
# 12     4.3          NaN   f25dy  Bar                         15
# 13     4.0          1.0   f25dv  Bar                         15
# 14     4.3          2.0   f25dv  Bar                         18
# 15     4.4          2.0   f25dv  Bar                         30
# 16     4.5          3.0   f25dv  Bar                         20
# 17     4.2          NaN   f25dy  Bar                         30
# 18     4.1          2.0   f25dv  Bar                         16
# 19     4.0          2.0   f25dv  Bar                         22
# 20     4.1          2.0   f25dy  Bar                         26
# 21     3.9          NaN   f25dy  Bar                         15
# 22     4.5          NaN   f25dy  Bar                         16
# 23     4.5          3.0   f25dv  Bar                         28
# 24     4.1          1.0   f25dv  Bar                         16
# 25     4.4          NaN   f25dv  Bar                         23
# 26     4.3          NaN   f25dv  Bar                         21
# 27     3.7          2.0   f25dv  Bar                         29
# 28     4.6          2.0   f25dv  Bar                         18
# 29     4.0          2.0   f25dy  Bar                         23
# 30     4.3          2.0   f25dy  Bar                         14
# 31     4.0          2.0   f25dy  Bar                         19
# 32     4.6          2.0   f25dy  Bar                         21
# 33     4.4          3.0   f25dy  Bar                         32
# 34     4.3          2.0   f25dy  Bar                         28
# 35     4.5          1.0   f25dv  Bar                         16
# 36     4.6          2.0   f25dy  Bar                         16
# 37     4.2          2.0   f25dy  Bar                         12
# 38     4.1          2.0   f25dv  Bar                         28
# 39     4.7          3.0   f25dy  Bar                         15
# 40     4.7          2.0   f25dy  Bar                         15
# 41     4.5          2.0   f25dy  Bar                         31
# 42     4.4          2.0   f25dy  Bar                         17
# 43     4.6          2.0   f25dv  Bar                         19
# 44     0.0          NaN   f25dy  Bar                         21
# 45     3.8          2.0   f25dy  Bar                         15
# 46     4.4          2.0   f25dv  Bar                         26
# 47     3.7          NaN   f25dv  Bar                         33
# 48     4.0          1.0   f25dv  Bar                         12
# 49     4.5          2.0   f25dv  Bar                         26
#
#     Nearby_Subway_Stations  Nearby_Light_Rail_Stations  Nearby_Stations  \
# 0                        3                           0               18
# 1                        9                          10               51
# 2                        7                           1               25
# 3                        8                           1               35
# 4                        6                           0               24
# 5                        7                          10               45
# 6                        7                           1               39
# 7                        3                           0               15
# 8                        4                           2               24
# 9                        9                          10               51
# 10                       7                          10               45
# 11                       3                           4               26
# 12                       8                           0               23
# 13                       4                           1               20
# 14                       5                           1               24
# 15                       9                          10               49
# 16                       5                           9               34
# 17                       7                          10               47
# 18                       3                           0               19
# 19                       5                           9               36
# 20                       3                           8               37
# 21                       6                           0               21
# 22                       8                           0               24
# 23                       7                          10               45
# 24                       7                           1               24
# 25                       7                          10               40
# 26                       6                          10               37
# 27                       8                           8               45
# 28                       7                           1               26
# 29                       8                           1               32
# 30                       6                           0               20
# 31                       3                           2               24
# 32                       4                           8               33
# 33                       9                          10               51
# 34                       8                           2               38
# 35                       5                           0               21
# 36                       7                           1               24
# 37                       4                           0               16
# 38                       8                          10               46
# 39                       4                           0               19
# 40                       3                           0               18
# 41                       8                           3               42
# 42                       3                           0               20
# 43                       5                           1               25
# 44                       4                           8               33
# 45                       3                           0               18
# 46                       7                          10               43
# 47                       7                          10               50
# 48                       2                           0               14
# 49                       8                           2               36
#
#     Is Outstanding  Exorbitant In Price  Nearby_Rail_Stations
# 0                0                    0                     3
# 1                0                    0                    19
# 2                0                    0                     8
# 3                0                    0                     9
# 4                0                    0                     6
# 5                0                    0                    17
# 6                0                    0                     8
# 7                1                    0                     3
# 8                0                    0                     6
# 9                0                    0                    19
# 10               0                    0                    17
# 11               1                    0                     7
# 12               0                    0                     8
# 13               0                    0                     5
# 14               0                    0                     6
# 15               0                    0                    19
# 16               1                    0                    14
# 17               0                    0                    17
# 18               0                    0                     3
# 19               0                    0                    14
# 20               0                    0                    11
# 21               0                    0                     6
# 22               1                    0                     8
# 23               1                    0                    17
# 24               0                    0                     8
# 25               0                    0                    17
# 26               0                    0                    16
# 27               0                    0                    16
# 28               1                    0                     8
# 29               0                    0                     9
# 30               0                    0                     6
# 31               0                    0                     5
# 32               1                    0                    12
# 33               0                    0                    19
# 34               0                    0                    10
# 35               1                    0                     5
# 36               1                    0                     8
# 37               0                    0                     4
# 38               0                    0                    18
# 39               1                    0                     4
# 40               1                    0                     3
# 41               1                    0                    11
# 42               0                    0                     3
# 43               1                    0                     6
# 44               0                    0                    12
# 45               0                    0                     3
# 46               0                    0                    17
# 47               0                    0                    17
# 48               0                    0                     2
# 49               1                    0                    10

# %%
bars_in_montreal_collected_unique_utf8['Nearby_CityBikes_Stations'] = count_nearby_stations(bars_coords, citybikes_coords, 1)

# %%
bars_in_montreal_collected_unique_utf8['Nearby_Subway_Stations'] = count_nearby_stations(bars_coords, subway_coords, 1)

# %%
bars_in_montreal_collected_unique_utf8['Nearby_Light_Rail_Stations'] = count_nearby_stations(bars_coords, light_rail_coords, 1)

# %%
bars_in_montreal_collected_unique_utf8['Nearby_Stations'] = count_nearby_stations(bars_coords, transport_station_coords, 1)

# %%
bars_mv_reg = bars_in_montreal_collected_unique_utf8

# %%
bars_mv_reg.to_csv('bars_mv_reg')

# %%
bars_mv_reg.head(50)
# Out:
#                                          Name  \
# 0                                 Pub St-Paul
# 1                                 Piranha Bar
# 2                               Patrick's Pub
# 3                       MVP Resto-Bar Sportif
# 4                           Pub John Michaels
# 5           Peel Pub - Sports Bar/Bar Sportif
# 6                                   Bar Macao
# 7                                BreWskey Pub
# 8                               Bar Tipsy Cow
# 9    LE VIEUX/ THE OLD DUBLIN PUB & RESTURANT
# 10                               McLean's Pub
# 11                         Pub Wolf & Workman
# 12                                  Normandie
# 13                     Bar Bifteck St-Laurent
# 14                Ye Olde Orchard Pub & Grill
# 15                                       NYKS
# 16                                 Bar George
# 17   Bartizen - Salle d'événement & Bar Privé
# 18                               Bar L'Barouf
# 19                    Winnie's Bar Restaurant
# 20                  Sir Winston Churchill Pub
# 21                               Pub Victoria
# 22                                    Le Date
# 23                                Bar MINĒRAL
# 24                               Bar Dominion
# 25                        Bevo Bar + Pizzeria
# 26                                  Point Bar
# 27                         Flâneur Bar Lounge
# 28                                  Alice Bar
# 29                                    La Cage
# 30                        La Distillerie no.1
# 31                          Ginkgo Café & Bar
# 32                                 Bar Renard
# 33                               Philemon Bar
# 34                           Pub Saint Pierre
# 35                       Monsieur café & vins
# 36                             Taverne Midway
# 37                               Le P'tit Bar
# 38                            PointBar Lounge
# 39                          Saloon Bistro Bar
# 40  Bar et Restaurant La Catrina - Vieux-Port
# 41                                  Bar Furco
# 42                               The Coldroom
# 43                             El Pequeño Bar
# 44                      Bar Le Mal Nécessaire
# 45                                    Modavie
# 46          Bootlegger cocktail bar & cuisine
# 47                                Bar Exotica
# 48        Resto-Bar-Café-Breakfast LA BARAQUE
# 49                        MajesThé Bistro Bar
#
#                                               Address   Latitude  Longitude  \
# 0          124 Rue Saint-Paul E, Montréal, QC H2Y 1G6  45.506944 -73.552500
# 1   680 Saint-Catherine St W, Montreal, Quebec H3B...  45.502852 -73.569942
# 2       1707 Saint Denis St, Montreal, Quebec H2X 3K4  45.515570 -73.564079
# 3     200 St Catherine St E, Montreal, Quebec H2X 1L1  45.511730 -73.561981
# 4       458 Pl. Jacques-Cartier, Montréal, QC H2Y 3Z2  45.508011 -73.553953
# 5              1196 Peel St, Montreal, Quebec H3B 2T6  45.499403 -73.571943
# 6      1057 St Laurent Blvd, Montreal, Quebec H2Z 1J6  45.508327 -73.560176
# 7          380 Rue Saint-Paul E, Montréal, QC H2Y 1H3  45.509398 -73.551386
# 8         3575 Av du Parc #4110, Montréal, QC H2X 3P9  45.510275 -73.575045
# 9              636 Rue Cathcart, Montréal, QC H3B 1L9  45.503008 -73.568646
# 10             1210 Peel St, Montreal, Quebec H3B 2T6  45.499530 -73.572134
# 11      139 Saint-Paul St W, Montreal, Quebec H2Y 1Z5  45.503730 -73.554861
# 12             1295 R. Atateken, Montréal, QC H2L 3K9  45.517301 -73.556479
# 13     3702 St Laurent Blvd, Montreal, Quebec H2X 2V4  45.514590 -73.574364
# 14    20 Prince Arthur St W, Montreal, Quebec H2X 1S3  45.513500 -73.572720
# 15           1250 Rue de Bleury, Montréal, QC H3B 2W4  45.506032 -73.566683
# 16  Le Mount Stephen, 1440 Drummond St, Montreal, ...  45.499044 -73.575778
# 17   901 Rue du Square-Victoria, Montréal, QC H2Z 1R1  45.502078 -73.562166
# 18      4171 Saint Denis St, Montreal, Quebec H2W 2M3  45.521809 -73.577784
# 19         1455 Crescent St, Montreal, Quebec H3G 2B2  45.497962 -73.576909
# 20         1455 Crescent St, Montreal, Quebec H3G 2B2  45.497911 -73.576891
# 21      698 Notre-Dame St W, Montreal, Quebec H3C 1J2  45.500004 -73.560042
# 22   1218 St Catherine St E, Montreal, Quebec H2L 2G9  45.518565 -73.555889
# 23             1641 R. Atateken, Montréal, QC H2L 3L4  45.518798 -73.559708
# 24         1243 Metcalfe St, Montreal, Quebec H3B 2V5  45.500611 -73.571538
# 25         410 R. Saint-Vincent, Montréal, QC H2Y 3A5  45.507020 -73.553286
# 26      2017 Saint Denis St, Montreal, Quebec H2X 3K8  45.516216 -73.565669
# 27        2050 Mansfield St, Montreal, Quebec H3A 1Y9  45.502519 -73.574411
# 28     1050 Sherbrooke St W, Montreal, Quebec H3A 2R6  45.502066 -73.576016
# 29  150 Rue Sainte-Catherine local 201C, Montréal,...  45.507652 -73.565356
# 30         300 Ontario St E, Montreal, Quebec H2X 1H6  45.514810 -73.565424
# 31  UQAM Pavillon J.-A.-DeSève, 308 rue Ste-Cather...  45.512692 -73.560853
# 32   1272 St Catherine St E, Montreal, Quebec H2L 2H2  45.519037 -73.555496
# 33      111 Saint-Paul St W, Montreal, Quebec H2Y 1Z5  45.504058 -73.554741
# 34         410 Rue Saint-Pierre, Montréal, QC H2Y 1Y3  45.501363 -73.556621
# 35           1102 Rue de Bleury, Montréal, QC H2Z 1N4  45.504696 -73.563817
# 36     1219 St Laurent Blvd, Montreal, Quebec H2X 2S6  45.509740 -73.563263
# 37      3451 Saint Denis St, Montreal, Quebec H2X 3L1  45.517522 -73.568365
# 38      1735 Saint Denis St, Montreal, Quebec H2X 3K4  45.515739 -73.564428
# 39   1333 St Catherine St E, Montreal, Quebec H2L 2H4  45.519898 -73.555104
# 40   119 De la Commune St W, Montreal, Quebec H2Y 2C7  45.503820 -73.553983
# 41             425 Mayor St, Montreal, Quebec H3A 1N9  45.505968 -73.569092
# 42             R. Saint-Vincent, Montréal, QC H2Y 1G8  45.507184 -73.553117
# 43        401a R. Saint-Vincent, Montréal, QC H2Y 3A4  45.507122 -73.553145
# 44    1106B St Laurent Blvd, Montreal, Quebec H2Z 1J5  45.508523 -73.561196
# 45        1 Saint-Paul St W, Montreal, Quebec H2Y 1Y6  45.505465 -73.553964
# 46  3481 St Laurent Blvd 2eme Etage, Montreal, Que...  45.513194 -73.570679
# 47         417 Rue Saint-Pierre, Montréal, QC H2Y 2M4  45.501522 -73.556726
# 48         401 R. Saint-Vincent, Montréal, QC H2Y 3A4  45.507079 -73.552991
# 49    2077 Blvd Robert-Bourassa, Montréal, QC H3A 2M3  45.504827 -73.572765
#
#     Rating  Price Level Geohash  Nearby_CityBikes_Stations  \
# 0      3.9          2.0   f25dy                         15
# 1      4.1          1.0   f25dv                         32
# 2      4.2          2.0   f25dy                         17
# 3      3.8          2.0   f25dy                         26
# 4      4.0          2.0   f25dy                         18
# 5      3.8          1.0   f25dv                         28
# 6      3.5          1.0   f25dy                         31
# 7      4.5          2.0   f25dy                         12
# 8      3.9          NaN   f25dv                         18
# 9      4.0          2.0   f25dv                         32
# 10     4.2          2.0   f25dv                         28
# 11     4.6          2.0   f25dy                         19
# 12     4.3          NaN   f25dy                         15
# 13     4.0          1.0   f25dv                         15
# 14     4.3          2.0   f25dv                         18
# 15     4.4          2.0   f25dv                         30
# 16     4.5          3.0   f25dv                         20
# 17     4.2          NaN   f25dy                         30
# 18     4.1          2.0   f25dv                         16
# 19     3.9          2.0   f25dv                         22
# 20     4.0          2.0   f25dv                         22
# 21     4.1          2.0   f25dy                         26
# 22     3.9          NaN   f25dy                         15
# 23     4.5          NaN   f25dy                         16
# 24     4.5          3.0   f25dv                         28
# 25     4.3          2.0   f25dy                         15
# 26     4.1          1.0   f25dv                         16
# 27     4.4          NaN   f25dv                         23
# 28     4.3          NaN   f25dv                         21
# 29     3.7          2.0   f25dv                         29
# 30     4.6          2.0   f25dv                         18
# 31     4.0          2.0   f25dy                         23
# 32     4.3          2.0   f25dy                         14
# 33     4.0          2.0   f25dy                         19
# 34     4.6          2.0   f25dy                         21
# 35     4.4          3.0   f25dy                         32
# 36     4.3          2.0   f25dy                         28
# 37     4.5          1.0   f25dv                         16
# 38     4.6          2.0   f25dy                         16
# 39     4.2          2.0   f25dy                         12
# 40     4.1          2.0   f25dy                         19
# 41     4.1          2.0   f25dv                         28
# 42     4.7          3.0   f25dy                         15
# 43     4.7          2.0   f25dy                         15
# 44     4.5          2.0   f25dy                         31
# 45     4.4          2.0   f25dy                         17
# 46     4.6          2.0   f25dv                         19
# 47     0.0          NaN   f25dy                         21
# 48     3.8          2.0   f25dy                         15
# 49     4.4          2.0   f25dv                         26
#
#     Nearby_Subway_Stations  Nearby_Light_Rail_Stations  Nearby_Stations
# 0                        3                           0               18
# 1                        9                          10               51
# 2                        7                           1               25
# 3                        8                           1               35
# 4                        6                           0               24
# 5                        7                          10               45
# 6                        7                           1               39
# 7                        3                           0               15
# 8                        4                           2               24
# 9                        9                          10               51
# 10                       7                          10               45
# 11                       3                           4               26
# 12                       8                           0               23
# 13                       4                           1               20
# 14                       5                           1               24
# 15                       9                          10               49
# 16                       5                           9               34
# 17                       7                          10               47
# 18                       3                           0               19
# 19                       5                           9               36
# 20                       5                           9               36
# 21                       3                           8               37
# 22                       6                           0               21
# 23                       8                           0               24
# 24                       7                          10               45
# 25                       5                           0               20
# 26                       7                           1               24
# 27                       7                          10               40
# 28                       6                          10               37
# 29                       8                           8               45
# 30                       7                           1               26
# 31                       8                           1               32
# 32                       6                           0               20
# 33                       3                           2               24
# 34                       4                           8               33
# 35                       9                          10               51
# 36                       8                           2               38
# 37                       5                           0               21
# 38                       7                           1               24
# 39                       4                           0               16
# 40                       3                           1               23
# 41                       8                          10               46
# 42                       4                           0               19
# 43                       3                           0               18
# 44                       8                           3               42
# 45                       3                           0               20
# 46                       5                           1               25
# 47                       4                           8               33
# 48                       3                           0               18
# 49                       7                          10               43

# %%
restaurants_in_montreal_collected_unique_utf8['Nearby_CityBikes_Stations'] = count_nearby_stations(restaurants_coords, citybikes_coords, 1)

# %%
restaurants_in_montreal_collected_unique_utf8['Nearby_Subway_Stations'] = count_nearby_stations(restaurants_coords, subway_coords, 1)

# %%
restaurants_in_montreal_collected_unique_utf8['Nearby_Light_Rail_Stations'] = count_nearby_stations(restaurants_coords, light_rail_coords, 1)

# %%
restaurants_in_montreal_collected_unique_utf8['Nearby_Stations'] = count_nearby_stations(restaurants_coords, transport_station_coords, 1)

# %%
restaurants_mv_reg = restaurants_in_montreal_collected_unique_utf8

# %%
restaurants_mv_reg.to_csv('restaurants_mv_reg')

# %%
restaurants_mv_reg = pd.read_csv('restaurants_mv_reg')

# %%
restaurants_mv_reg.head(50)
# Out:
#     Unnamed: 0                                               Name  \
# 0            0                                Restaurant Branzino
# 1            1          Bar et Restaurant La Catrina - Vieux-Port
# 2            2                      COMMODORE restaurant Montréal
# 3            3                               Restaurant Keung Kee
# 4            4                                 Beijing Restaurant
# 5            5                                   Restaurant Kamúy
# 6            6                                 Restaurant Boustan
# 7            7                 Restaurants Lafleur Place des arts
# 8            8                                       Poulet Rouge
# 9            9                                     Loaded Pierogi
# 10          10                Resto-Bar-Café-Breakfast LA BARAQUE
# 11          11                                  Restaurant Solmar
# 12          12                                         A&W Canada
# 13          13                                    Bellucci Italia
# 14          14                                Restaurant Le Carré
# 15          15                                      Trattoria Gio
# 16          16                                  Restaurant Pangea
# 17          17                                         A&W Canada
# 18          18                                  La Belle Province
# 19          19                                  Vargas Restaurant
# 20          20                                  Restaurant Gandhi
# 21          21                                     Shawarmaz UQAM
# 22          22                          3 Amigos (Vieux-Montréal)
# 23          23                          Piazza Sociale Restaurant
# 24          24                                  La Belle Province
# 25          25                           Hiatus Restaurant et Bar
# 26          26                                 Menthe et couscous
# 27          27                      Restaurant Chinatown Kim Fung
# 28          28                            Pincette - Bar à Homard
# 29          29                                   Asian restaurant
# 30          30                                  Circos Restaurant
# 31          31                                 Restaurant Sauvage
# 32          32                   Restaurant Le Coin Du Vieux Port
# 33          33  Estrella Restaurant - Bar - Salle de réception...
# 34          34                   Sushi Momo par Christian Ventura
# 35          35                                  Délicieux Mei Mei
# 36          36                           Restaurant & Bar Le Kube
# 37          37  Plateau Cuisine Indienne | Authentic Indian Re...
# 38          38                                 Restaurant Singh's
# 39          39                                  Restaurant Pastel
# 40          40                                             Jacopo
# 41          41                                    Restaurant Épik
# 42          42                                         McDonald's
# 43          43                                   Atrio Restaurant
# 44          44                                 Restaurant Mon Nan
# 45          45                             Restaurant & Bar Gault
# 46          46                             Asha Indian Restaurant
# 47          47                              Restaurant La Popessa
# 48          48                          Restaurant Noodle Factory
# 49          49                                         McDonald's
#
#                                               Address   Latitude  Longitude  \
# 0   50 René-Lévesque Blvd W, Montreal, Quebec H2Z 1A2  45.508147 -73.561650
# 1    119 De la Commune St W, Montreal, Quebec H2Y 2C7  45.503820 -73.553983
# 2   355 Blvd. De Maisonneuve Ouest, Montreal, Queb...  45.507151 -73.569114
# 3    70 Rue De la Gauchetière O, Montréal, QC H2Z 1C1  45.507253 -73.560407
# 4    92 Rue De la Gauchetière O, Montréal, QC H2Z 1C1  45.506930 -73.560560
# 5      1485 Jeanne-Mance St, Montreal, Quebec H2X 1Z9  45.507866 -73.567355
# 6      19 St Catherine St E, Montreal, Quebec H2X 1K3  45.510356 -73.563572
# 7   268 Saint-Catherine St W, Montreal, Quebec H2X...  45.506916 -73.566146
# 8       1750 Saint Denis St, Montreal, Quebec H2X 3K6  45.515736 -73.565138
# 9       1748 Saint Denis St, Montreal, Quebec H2X 3K6  45.515661 -73.565007
# 10         401 R. Saint-Vincent, Montréal, QC H2Y 3A4  45.507079 -73.552991
# 11         111 Rue Saint-Paul E, Montréal, QC H2Y 1G7  45.506904 -73.552960
# 12    330 St Catherine St E, Montreal, Quebec H2X 1L7  45.513100 -73.560880
# 13  200 Saint-Catherine St W, Montreal, Quebec H2X...  45.507145 -73.565677
# 14   1191 R. du Square-Phillips, Montréal, QC H3B 3C9  45.503578 -73.567288
# 15      452 Pl. Jacques-Cartier, Montréal, QC H2Y 3B3  45.507919 -73.553792
# 16         104 Rue Saint-Paul E, Montréal, QC H2Y 1G6  45.506664 -73.552863
# 17   48 Notre-Dame St. East, Montreal, Quebec H2Y 1B9  45.506838 -73.555139
# 18      1 St Catherine St E, Montreal, Quebec H2X 1K3  45.510031 -73.563867
# 19  690 René-Lévesque Blvd W, Montreal, Quebec H3B...  45.501517 -73.567471
# 20      230 Saint-Paul St W, Montreal, Quebec H2Y 1Z9  45.502189 -73.555478
# 21    277 St Catherine St E, Montreal, Quebec H2X 1L5  45.512570 -73.561618
# 22        200 Rue Saint-Jacques, Montréal, QC H2Y 1M1  45.503998 -73.558110
# 23  1 Pl. Monseigneur Charbonneau, Montreal, Quebe...  45.500996 -73.568808
# 24             1216 Peel St, Montreal, Quebec H3B 2T6  45.499444 -73.572222
# 25     1 Pl. Ville-Marie #46EME, Montréal, QC H3B 4E8  45.501309 -73.569677
# 26                361 Rue Émery, Montréal, QC H2X 1J2  45.514802 -73.563656
# 27  1111 Rue Saint-Urbain M05, Montreal, Quebec H2...  45.507718 -73.561808
# 28          94 Rue Saint-Paul E, Montréal, QC H2Y 1G6  45.506493 -73.553016
# 29  888 Saint Francois Xavier St, Montreal, Quebec...  45.504524 -73.558994
# 30      380 Sherbrooke St W, Montreal, Quebec H3A 0B1  45.507661 -73.571024
# 31         52 Rue Saint-Jacques, Montréal, QC H2Y 1L2  45.505598 -73.556826
# 32   121 De la Commune St W, Montreal, Quebec H2Y 2C7  45.503749 -73.553916
# 33     1165 St Laurent Blvd, Montreal, Quebec H2X 3Z5  45.509184 -73.561655
# 34      3609 Saint Denis St, Montreal, Quebec H2X 3L6  45.518112 -73.569495
# 35     1023 St Laurent Blvd, Montreal, Quebec H2Z 1J4  45.508094 -73.559698
# 36  Restaurant Hôtel, 900 Rue De la Gauchetière O,...  45.499151 -73.565686
# 37                930 Rue Roy E, Montréal, QC H2L 1E7  45.521969 -73.569686
# 38     3712 St Laurent Blvd, Montreal, Quebec H2X 2V4  45.514641 -73.574514
# 39            124 McGill St, Montreal, Quebec H2Y 2E5  45.499540 -73.555859
# 40      436 Pl. Jacques-Cartier, Montréal, QC H2Y 3B3  45.507727 -73.553279
# 41      171 Saint-Paul St W, Montreal, Quebec H2Y 1Z5  45.503125 -73.555164
# 42  640 Saint-Catherine St W, Montreal, Quebec H3B...  45.503325 -73.569439
# 43      206 Rue Saint-Antoine O, Montréal, QC H2Z 1H5  45.504328 -73.559263
# 44    43 R. de la Gauchetière E, Montréal, QC H2X 1P4  45.508602 -73.559750
# 45     449 Sainte Hélène St, Montreal, Quebec H2Y 2K9  45.501488 -73.558267
# 46            3490 Park Ave, Montreal, Quebec H2X 2H5  45.509245 -73.573524
# 47      115 Rue Saint-Antoine O, Montréal, QC H2Z 1X8  45.505539 -73.558676
# 48        1018 Rue Saint-Urbain, Montréal, QC H2Z 1K6  45.506757 -73.560760
# 49    850 St Catherine St E, Montreal, Quebec H2L 2E2  45.515749 -73.558440
#
#     Rating  Price Level Geohash  Nearby_CityBikes_Stations  \
# 0      3.9          NaN   f25dy                         30
# 1      4.1          2.0   f25dy                         19
# 2      3.9          NaN   f25dv                         26
# 3      3.9          2.0   f25dy                         30
# 4      4.1          2.0   f25dy                         28
# 5      4.4          NaN   f25dv                         28
# 6      4.1          1.0   f25dy                         27
# 7      3.5          1.0   f25dv                         27
# 8      4.4          2.0   f25dv                         17
# 9      4.0          NaN   f25dv                         17
# 10     3.8          2.0   f25dy                         15
# 11     4.2          NaN   f25dy                         15
# 12     3.6          1.0   f25dy                         23
# 13     4.2          NaN   f25dv                         27
# 14     4.7          NaN   f25dv                         31
# 15     4.1          2.0   f25dy                         17
# 16     3.6          4.0   f25dy                         15
# 17     3.9          1.0   f25dy                         17
# 18     3.6          1.0   f25dy                         27
# 19     4.1          3.0   f25dv                         32
# 20     3.9          3.0   f25dy                         19
# 21     4.6          NaN   f25dy                         23
# 22     4.6          NaN   f25dy                         26
# 23     3.7          NaN   f25dv                         33
# 24     3.9          1.0   f25dv                         28
# 25     4.4          4.0   f25dv                         31
# 26     4.2          2.0   f25dy                         20
# 27     3.8          2.0   f25dy                         31
# 28     4.3          NaN   f25dy                         16
# 29     0.0          NaN   f25dy                         26
# 30     3.5          NaN   f25dv                         25
# 31     3.9          NaN   f25dy                         24
# 32     2.3          NaN   f25dy                         19
# 33     4.4          NaN   f25dy                         31
# 34     4.7          2.0   f25dv                         16
# 35     4.1          NaN   f25dy                         30
# 36     3.4          NaN   f25dv                         33
# 37     4.6          NaN   f25dv                         16
# 38     4.2          2.0   f25dv                         14
# 39     4.7          4.0   f25dy                         18
# 40     4.4          NaN   f25dy                         17
# 41     5.0          NaN   f25dy                         18
# 42     3.2          1.0   f25dv                         31
# 43     0.0          NaN   f25dy                         26
# 44     4.3          2.0   f25dy                         31
# 45     5.0          NaN   f25dy                         24
# 46     3.1          NaN   f25dv                         20
# 47     4.1          2.0   f25dy                         25
# 48     4.4          NaN   f25dy                         28
# 49     2.9          1.0   f25dy                         18
#
#     Nearby_Subway_Stations  Nearby_Light_Rail_Stations  Nearby_Stations
# 0                        8                           6               44
# 1                        3                           1               23
# 2                        7                           9               42
# 3                        8                           7               45
# 4                        8                           8               44
# 5                        9                           8               45
# 6                        9                           2               38
# 7                       10                          10               47
# 8                        7                           1               25
# 9                        7                           1               25
# 10                       3                           0               18
# 11                       3                           0               18
# 12                       8                           1               32
# 13                       9                           9               45
# 14                       9                          10               50
# 15                       6                           0               23
# 16                       3                           0               18
# 17                       5                           0               22
# 18                       9                           2               38
# 19                       7                          10               49
# 20                       4                           8               31
# 21                       8                           1               32
# 22                       7                           9               42
# 23                       8                          10               51
# 24                       7                          10               45
# 25                       8                          10               49
# 26                       7                           1               28
# 27                       8                           7               46
# 28                       3                           0               19
# 29                       8                          10               44
# 30                       7                           7               39
# 31                       6                           5               35
# 32                       3                           1               23
# 33                       8                           2               41
# 34                       4                           0               20
# 35                       7                           1               38
# 36                       7                          10               50
# 37                       2                           0               18
# 38                       4                           1               19
# 39                       3                           8               29
# 40                       4                           0               21
# 41                       3                           5               26
# 42                       9                          10               50
# 43                       8                          10               44
# 44                       7                           1               39
# 45                       4                           8               36
# 46                       5                           2               27
# 47                       6                           8               39
# 48                       8                           8               44
# 49                       6                           0               24

# %% [markdown]
# ## Multivariable Regression Analysis

# %% [markdown]
# ### First do the analysis for all establishments

# %%
bars_and_restaurants_mv_reg = bars_and_restaurants_mv_reg.dropna(subset=['Nearby_CityBikes_Stations', 'Nearby_Subway_Stations', 'Nearby_Light_Rail_Stations', 'Rating'])

# %%
X = bars_and_restaurants_mv_reg[['Nearby_CityBikes_Stations', 'Nearby_Subway_Stations', 'Nearby_Light_Rail_Stations']]
y = bars_and_restaurants_mv_reg['Rating']

# %%
# Add a constant
X = sm.add_constant(X)

# %%
# Create the model
model = sm.OLS(y, X).fit()

# %%
# Print out the statistics
model_summary = model.summary()
print(model_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     5.637
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):           0.000752
# Time:                        22:49:27   Log-Likelihood:                -4281.4
# No. Observations:                3191   AIC:                             8571.
# Df Residuals:                    3187   BIC:                             8595.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          3.9577      0.022    182.406      0.000       3.915       4.000
# Nearby_CityBikes_Stations      0.0139      0.004      3.496      0.000       0.006       0.022
# Nearby_Subway_Stations        -0.0130      0.014     -0.957      0.338      -0.040       0.014
# Nearby_Light_Rail_Stations    -0.0252      0.010     -2.504      0.012      -0.045      -0.005
# ==============================================================================
# Omnibus:                     1978.975   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17290.530
# Skew:                          -2.940   Prob(JB):                         0.00
# Kurtosis:                      12.771   Cond. No.                         14.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('multivariable_regression_results_b_r.csv', 'w') as f:
    f.write(summary_as_csv)

# %% [markdown]
# #### This is a very low R squared value. I will check if eliminating subways stations, which apparently is not a statistically significant factor, improves results

# %%
X = bars_and_restaurants_df_no_duplicates_utf8[['Nearby_CityBikes_Stations', 'Nearby_Light_Rail_Stations']]
y = bars_and_restaurants_df_no_duplicates_utf8['Rating']

# %%
# Add a constant
X = sm.add_constant(X)

# %%
# Create the model
model = sm.OLS(y, X).fit()

# %%
# Print out the statistics
model_summary = model.summary()
print(model_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     7.997
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):           0.000343
# Time:                        22:52:25   Log-Likelihood:                -4281.8
# No. Observations:                3191   AIC:                             8570.
# Df Residuals:                    3188   BIC:                             8588.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          3.9503      0.020    194.843      0.000       3.911       3.990
# Nearby_CityBikes_Stations      0.0112      0.003      3.989      0.000       0.006       0.017
# Nearby_Light_Rail_Stations    -0.0259      0.010     -2.577      0.010      -0.046      -0.006
# ==============================================================================
# Omnibus:                     1978.231   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17271.124
# Skew:                          -2.939   Prob(JB):                         0.00
# Kurtosis:                      12.765   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('multivariable_regression_results_b_r_no_subway.csv', 'w') as f:
    f.write(summary_as_csv)

# %% [markdown]
# #### Removing subway stations as an independent variable did not make the results more significant

# %% [markdown]
# ### Now do regression for just bars.

# %%
bars_in_montreal_dropna = bars_mv_reg.dropna(subset=['Nearby_CityBikes_Stations', 'Nearby_Subway_Stations', 'Nearby_Light_Rail_Stations', 'Rating'])

# %%
X = bars_in_montreal_dropna[['Nearby_CityBikes_Stations', 'Nearby_Subway_Stations', 'Nearby_Light_Rail_Stations']]
y = bars_in_montreal_dropna['Rating']

# %%
# Add a constant
X = sm.add_constant(X)

# %%
# Create the model
model = sm.OLS(y, X).fit()

# %%
# Print out the statistics
model_summary = model.summary()
print(model_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     3.879
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):            0.00923
# Time:                        22:53:35   Log-Likelihood:                -455.75
# No. Observations:                 523   AIC:                             919.5
# Df Residuals:                     519   BIC:                             936.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          4.0766      0.038    106.345      0.000       4.001       4.152
# Nearby_CityBikes_Stations     -0.0004      0.006     -0.067      0.946      -0.012       0.011
# Nearby_Subway_Stations         0.0369      0.020      1.855      0.064      -0.002       0.076
# Nearby_Light_Rail_Stations    -0.0368      0.012     -2.964      0.003      -0.061      -0.012
# ==============================================================================
# Omnibus:                      499.203   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16969.214
# Skew:                          -4.227   Prob(JB):                         0.00
# Kurtosis:                      29.594   Cond. No.                         20.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('multivariable_regression_results_b.csv', 'w') as f:
    f.write(summary_as_csv)

# %%
X = bars_in_montreal_dropna[['Nearby_Subway_Stations', 'Nearby_Light_Rail_Stations']]
y = bars_in_montreal_dropna['Rating']

# %%
# Add a constant
X = sm.add_constant(X)

# %%
# Create the model
model = sm.OLS(y, X).fit()

# %%
# Print out the statistics
model_summary = model.summary()
print(model_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     5.827
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):            0.00314
# Time:                        22:54:27   Log-Likelihood:                -455.75
# No. Observations:                 523   AIC:                             917.5
# Df Residuals:                     520   BIC:                             930.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          4.0758      0.037    110.722      0.000       4.004       4.148
# Nearby_Subway_Stations         0.0359      0.013      2.691      0.007       0.010       0.062
# Nearby_Light_Rail_Stations    -0.0371      0.011     -3.322      0.001      -0.059      -0.015
# ==============================================================================
# Omnibus:                      499.333   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16985.110
# Skew:                          -4.228   Prob(JB):                         0.00
# Kurtosis:                      29.607   Cond. No.                         6.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('multivariable_regression_results_b_no_bikes.csv', 'w') as f:
    f.write(summary_as_csv)

# %% [markdown]
# ### Now do regression for just restaurants.

# %%
restaurants_mv_reg = restaurants_mv_reg.dropna(subset=['Nearby_CityBikes_Stations', 'Nearby_Subway_Stations', 'Nearby_Light_Rail_Stations', 'Rating'])

# %%
X = restaurants_mv_reg[['Nearby_CityBikes_Stations', 'Nearby_Subway_Stations', 'Nearby_Light_Rail_Stations']]
y = restaurants_mv_reg['Rating']

# %%
# Add a constant
X = sm.add_constant(X)

# %%
# Create the model
model = sm.OLS(y, X).fit()

# %%
# Print out the statistics
model_summary = model.summary()
print(model_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     4.245
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):            0.00531
# Time:                        22:55:04   Log-Likelihood:                -3825.4
# No. Observations:                2772   AIC:                             7659.
# Df Residuals:                    2768   BIC:                             7682.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          3.9493      0.024    166.105      0.000       3.903       3.996
# Nearby_CityBikes_Stations      0.0151      0.005      3.314      0.001       0.006       0.024
# Nearby_Subway_Stations        -0.0223      0.015     -1.438      0.151      -0.053       0.008
# Nearby_Light_Rail_Stations    -0.0208      0.012     -1.740      0.082      -0.044       0.003
# ==============================================================================
# Omnibus:                     1636.410   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12428.331
# Skew:                          -2.807   Prob(JB):                         0.00
# Kurtosis:                      11.722   Cond. No.                         13.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('multivariable_regression_results_r.csv', 'w') as f:
    f.write(summary_as_csv)

# %% [markdown]
# #### Dropping Subway Stations As It Is Not Statistically Significant

# %%
X = restaurants_mv_reg[['Nearby_CityBikes_Stations', 'Nearby_Light_Rail_Stations']]
y = restaurants_mv_reg['Rating']

# %%
# Add a constant
X = sm.add_constant(X)

# %%
# Create the model
model = sm.OLS(y, X).fit()

# %%
# Print out the statistics
model_summary = model.summary()
print(model_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     5.332
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):            0.00488
# Time:                        22:59:23   Log-Likelihood:                -3826.4
# No. Observations:                2772   AIC:                             7659.
# Df Residuals:                    2769   BIC:                             7677.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          3.9363      0.022    178.854      0.000       3.893       3.979
# Nearby_CityBikes_Stations      0.0105      0.003      3.219      0.001       0.004       0.017
# Nearby_Light_Rail_Stations    -0.0220      0.012     -1.841      0.066      -0.045       0.001
# ==============================================================================
# Omnibus:                     1635.161   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12399.604
# Skew:                          -2.805   Prob(JB):                         0.00
# Kurtosis:                      11.711   Cond. No.                         11.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('multivariable_regression_results_r_no_subway.csv', 'w') as f:
    f.write(summary_as_csv)

# %% [markdown]
# #### Dropping Light Rail Stations As Well

# %%
X = restaurants_mv_reg[['Nearby_CityBikes_Stations']]
y = restaurants_mv_reg['Rating']

# %%
# Add a constant
X = sm.add_constant(X)

# %%
# Create the model
model = sm.OLS(y, X).fit()

# %%
# Print out the statistics
model_summary = model.summary()
print(model_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     7.269
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):            0.00706
# Time:                        23:00:40   Log-Likelihood:                -3828.1
# No. Observations:                2772   AIC:                             7660.
# Df Residuals:                    2770   BIC:                             7672.
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         3.9410      0.022    180.213      0.000       3.898       3.984
# Nearby_CityBikes_Stations     0.0063      0.002      2.696      0.007       0.002       0.011
# ==============================================================================
# Omnibus:                     1632.980   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12341.426
# Skew:                          -2.802   Prob(JB):                         0.00
# Kurtosis:                      11.686   Cond. No.                         11.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('simple_regression_results_r_citybikes.csv', 'w') as f:
    f.write(summary_as_csv)

# %% [markdown]
# ## I will now perform a logistic regression analysis to see if the number of nearby transit stations is predictive of whether or not an establishment is rated as "Outstanding" (rating of 4.5 or above) or is exhorbiant in price (has a price level of 4).

# %%
bars_and_restaurants_mv_reg['Exorbitant In Price'] = (bars_and_restaurants_mv_reg['Price Level'] >= 4.0).astype(int)

# %%
bars_and_restaurants_mv_reg['Is Outstanding'] = (bars_and_restaurants_mv_reg['Rating'] >= 4.5).astype(int)

# %%
bars_and_restaurants_mv_reg['Nearby_Rail_Stations'] = (bars_and_restaurants_mv_reg['Nearby_Subway_Stations'] + bars_and_restaurants_mv_reg['Nearby_Light_Rail_Stations'])

# %%
bars_and_restaurants_mv_reg
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                                        Pub St-Paul
# 1              1                                        Piranha Bar
# 2              2                                      Patrick's Pub
# 3              3                              MVP Resto-Bar Sportif
# 4              4                                  Pub John Michaels
# ...          ...                                                ...
# 3186        3186                  Les Enfants Terribles — Outremont
# 3187        3187                       Pho Bep Cuisine Vietnamienne
# 3188        3188                                       Yuukai sushi
# 3189        3189                           Pizzeria Magpie Mile End
# 3190        3190  Sushi Momo Le Comptoir - Takeout Counter Par C...
#
#                                                 Address   Latitude  Longitude  \
# 0            124 Rue Saint-Paul E, Montréal, QC H2Y 1G6  45.506944 -73.552500
# 1     680 Saint-Catherine St W, Montreal, Quebec H3B...  45.502852 -73.569942
# 2         1707 Saint Denis St, Montreal, Quebec H2X 3K4  45.515570 -73.564079
# 3       200 St Catherine St E, Montreal, Quebec H2X 1L1  45.511730 -73.561981
# 4         458 Pl. Jacques-Cartier, Montréal, QC H2Y 3Z2  45.508011 -73.553953
# ...                                                 ...        ...        ...
# 3186        1257 Bernard Ave, Outremont, Quebec H2V 1V8  45.519924 -73.609135
# 3187      102 Rue Saint-Viateur O, Montréal, QC H2T 2L1  45.524414 -73.600046
# 3188            5407 Park Ave, Montreal, Quebec H2V 4G9  45.522069 -73.601220
# 3189            16 Maguire St, Montreal, Quebec H2T 1B8  45.524703 -73.595522
# 3190          16 Ave des Pins, Montreal, Quebec H2W 1N3  45.515266 -73.574704
#
#       Rating  Price Level Geohash        Type  Nearby_CityBikes_Stations  \
# 0        3.9          2.0   f25dy         Bar                         15
# 1        4.1          1.0   f25dv         Bar                         32
# 2        4.2          2.0   f25dy         Bar                         17
# 3        3.8          2.0   f25dy         Bar                         26
# 4        4.0          2.0   f25dy         Bar                         18
# ...      ...          ...     ...         ...                        ...
# 3186     3.9          3.0   f25du  Restaurant                          2
# 3187     4.5          NaN   f25dv  Restaurant                         11
# 3188     4.5          2.0   f25dv  Restaurant                          8
# 3189     4.4          2.0   f25dv  Restaurant                         14
# 3190     4.4          NaN   f25dv  Restaurant                         13
#
#       Nearby_Subway_Stations  Nearby_Light_Rail_Stations  Nearby_Stations  \
# 0                          3                           0               18
# 1                          9                          10               51
# 2                          7                           1               25
# 3                          8                           1               35
# 4                          6                           0               24
# ...                      ...                         ...              ...
# 3186                       1                           0                3
# 3187                       1                           0               12
# 3188                       0                           0                8
# 3189                       2                           0               16
# 3190                       4                           1               18
#
#       Is Outstanding  Exorbitant In Price  Nearby_Rail_Stations
# 0                  0                    0                     3
# 1                  0                    0                    19
# 2                  0                    0                     8
# 3                  0                    0                     9
# 4                  0                    0                     6
# ...              ...                  ...                   ...
# 3186               0                    0                     1
# 3187               1                    0                     1
# 3188               1                    0                     0
# 3189               0                    0                     2
# 3190               0                    0                     5
#
# [3191 rows x 16 columns]

# %%
bars_mv_reg['Exorbitant In Price'] = (bars_mv_reg['Price Level'] >= 4.0).astype(int)

# %%
bars_mv_reg['Is Outstanding'] = (bars_mv_reg['Rating'] >= 4.0).astype(int)

# %%
bars_mv_reg['Nearby_Rail_Stations'] = (bars_mv_reg['Nearby_Subway_Stations'] + bars_mv_reg['Nearby_Light_Rail_Stations'])

# %%
bars_mv_reg
# Out:
#                       Name                                            Address  \
# 0              Pub St-Paul         124 Rue Saint-Paul E, Montréal, QC H2Y 1G6
# 1              Piranha Bar  680 Saint-Catherine St W, Montreal, Quebec H3B...
# 2            Patrick's Pub      1707 Saint Denis St, Montreal, Quebec H2X 3K4
# 3    MVP Resto-Bar Sportif    200 St Catherine St E, Montreal, Quebec H2X 1L1
# 4        Pub John Michaels      458 Pl. Jacques-Cartier, Montréal, QC H2Y 3Z2
# ..                     ...                                                ...
# 518            M Resto-Bar       3625 Rue Talon, Sainte-Catherine, QC J5C 1T7
# 519        BLVD Bar & Gril            100 Rue Kepler, Châteauguay, QC J6K 2X9
# 520               Barbossa   3956 A St Laurent Blvd, Montreal, Quebec H2W 1Y3
# 521   KARAOKE BAR 3 MINOTS     3812 St Laurent Blvd, Montreal, Quebec H2W 1X6
# 522  Castello Resto Lounge             615 Bd Curé-Labelle, Laval, QC H7V 2T8
#
#       Latitude  Longitude  Rating  Price Level Geohash  \
# 0    45.506944 -73.552500     3.9          2.0   f25dy
# 1    45.502852 -73.569942     4.1          1.0   f25dv
# 2    45.515570 -73.564079     4.2          2.0   f25dy
# 3    45.511730 -73.561981     3.8          2.0   f25dy
# 4    45.508011 -73.553953     4.0          2.0   f25dy
# ..         ...        ...     ...          ...     ...
# 518  45.387405 -73.553055     4.4          2.0   f25dn
# 519  45.360540 -73.712815     4.5          2.0   f25d4
# 520  45.516651 -73.578985     4.1          2.0   f25dv
# 521  45.515533 -73.576472     3.4          1.0   f25dv
# 522  45.537344 -73.742808     4.2          2.0   f25e1
#
#      Nearby_CityBikes_Stations  Nearby_Subway_Stations  \
# 0                           15                       3
# 1                           32                       9
# 2                           17                       7
# 3                           26                       8
# 4                           18                       6
# ..                         ...                     ...
# 518                          0                       0
# 519                          0                       0
# 520                         10                       2
# 521                         13                       1
# 522                          0                       0
#
#      Nearby_Light_Rail_Stations  Nearby_Stations  Exorbitant In Price  \
# 0                             0               18                    0
# 1                            10               51                    0
# 2                             1               25                    0
# 3                             1               35                    0
# 4                             0               24                    0
# ..                          ...              ...                  ...
# 518                           0                0                    0
# 519                           0                0                    0
# 520                           0               12                    0
# 521                           0               14                    0
# 522                           0                0                    0
#
#      Is Outstanding  Nearby_Rail_Stations
# 0                 0                     3
# 1                 1                    19
# 2                 1                     8
# 3                 0                     9
# 4                 1                     6
# ..              ...                   ...
# 518               1                     0
# 519               1                     0
# 520               1                     2
# 521               0                     1
# 522               1                     0
#
# [523 rows x 14 columns]

# %%
restaurants_mv_reg['Exorbitant In Price'] = (restaurants_mv_reg['Price Level'] >= 4.0).astype(int)

# %%
restaurants_mv_reg['Is Outstanding'] = (restaurants_mv_reg['Rating'] >= 4.0).astype(int)

# %%
restaurants_mv_reg['Nearby_Rail_Stations'] = (restaurants_mv_reg['Nearby_Subway_Stations'] + restaurants_mv_reg['Nearby_Light_Rail_Stations'])

# %%
restaurants_mv_reg
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                                Restaurant Branzino
# 1              1          Bar et Restaurant La Catrina - Vieux-Port
# 2              2                      COMMODORE restaurant Montréal
# 3              3                               Restaurant Keung Kee
# 4              4                                 Beijing Restaurant
# ...          ...                                                ...
# 2767        2767                  Les Enfants Terribles — Outremont
# 2768        2768                       Pho Bep Cuisine Vietnamienne
# 2769        2769                                       Yuukai sushi
# 2770        2770                           Pizzeria Magpie Mile End
# 2771        2771  Sushi Momo Le Comptoir - Takeout Counter Par C...
#
#                                                 Address   Latitude  Longitude  \
# 0     50 René-Lévesque Blvd W, Montreal, Quebec H2Z 1A2  45.508147 -73.561650
# 1      119 De la Commune St W, Montreal, Quebec H2Y 2C7  45.503820 -73.553983
# 2     355 Blvd. De Maisonneuve Ouest, Montreal, Queb...  45.507151 -73.569114
# 3      70 Rue De la Gauchetière O, Montréal, QC H2Z 1C1  45.507253 -73.560407
# 4      92 Rue De la Gauchetière O, Montréal, QC H2Z 1C1  45.506930 -73.560560
# ...                                                 ...        ...        ...
# 2767        1257 Bernard Ave, Outremont, Quebec H2V 1V8  45.519924 -73.609135
# 2768      102 Rue Saint-Viateur O, Montréal, QC H2T 2L1  45.524414 -73.600046
# 2769            5407 Park Ave, Montreal, Quebec H2V 4G9  45.522069 -73.601220
# 2770            16 Maguire St, Montreal, Quebec H2T 1B8  45.524703 -73.595522
# 2771          16 Ave des Pins, Montreal, Quebec H2W 1N3  45.515266 -73.574704
#
#       Rating  Price Level Geohash  Nearby_CityBikes_Stations  \
# 0        3.9          NaN   f25dy                         30
# 1        4.1          2.0   f25dy                         19
# 2        3.9          NaN   f25dv                         26
# 3        3.9          2.0   f25dy                         30
# 4        4.1          2.0   f25dy                         28
# ...      ...          ...     ...                        ...
# 2767     3.9          3.0   f25du                          2
# 2768     4.5          NaN   f25dv                         11
# 2769     4.5          2.0   f25dv                          8
# 2770     4.4          2.0   f25dv                         14
# 2771     4.4          NaN   f25dv                         13
#
#       Nearby_Subway_Stations  Nearby_Light_Rail_Stations  Nearby_Stations  \
# 0                          8                           6               44
# 1                          3                           1               23
# 2                          7                           9               42
# 3                          8                           7               45
# 4                          8                           8               44
# ...                      ...                         ...              ...
# 2767                       1                           0                3
# 2768                       1                           0               12
# 2769                       0                           0                8
# 2770                       2                           0               16
# 2771                       4                           1               18
#
#       Exorbitant In Price  Is Outstanding  Nearby_Rail_Stations
# 0                       0               0                    14
# 1                       0               1                     4
# 2                       0               0                    16
# 3                       0               0                    15
# 4                       0               1                    16
# ...                   ...             ...                   ...
# 2767                    0               0                     1
# 2768                    0               1                     1
# 2769                    0               1                     0
# 2770                    0               1                     2
# 2771                    0               1                     5
#
# [2772 rows x 15 columns]

# %% [markdown]
# ### Logistic Regression For Bars And Restaurants For All Transit

# %%
X = bars_and_restaurants_mv_reg[['Nearby_Stations']]  # Independent variable
y = bars_and_restaurants_mv_reg['Is Outstanding']     # Dependent variable

# %%
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)

# %%
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.590370
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         Is Outstanding   No. Observations:                 3191
# Model:                          Logit   Df Residuals:                     3189
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 24 Mar 2024   Pseudo R-squ.:               9.468e-05
# Time:                        23:02:30   Log-Likelihood:                -1883.9
# converged:                       True   LL-Null:                       -1884.0
# Covariance Type:            nonrobust   LLR p-value:                    0.5503
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -0.9747      0.049    -19.981      0.000      -1.070      -0.879
# Nearby_Stations     0.0020      0.003      0.599      0.549      -0.005       0.009
# ===================================================================================

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('logistic_is_outstanding_all_stations_b_r.csv', 'w') as f:
    f.write(summary_as_csv)

# %%
X = bars_and_restaurants_mv_reg[['Nearby_Stations']]  # Independent variable
y = bars_and_restaurants_mv_reg['Exorbitant In Price']     # Dependent variable

# %%
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)

# %%
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.033484
#          Iterations 10
#                             Logit Regression Results
# ===============================================================================
# Dep. Variable:     Exorbitant In Price   No. Observations:                 3191
# Model:                           Logit   Df Residuals:                     3189
# Method:                            MLE   Df Model:                            1
# Date:                 Sun, 24 Mar 2024   Pseudo R-squ.:                 0.08122
# Time:                         23:04:44   Log-Likelihood:                -106.85
# converged:                        True   LL-Null:                       -116.29
# Covariance Type:             nonrobust   LLR p-value:                 1.385e-05
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -6.0005      0.371    -16.184      0.000      -6.727      -5.274
# Nearby_Stations     0.0609      0.013      4.723      0.000       0.036       0.086
# ===================================================================================

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('logistic_is_exorbitant_all_stations_b_r.csv', 'w') as f:
    f.write(summary_as_csv)

# %%
X = bars_mv_reg[['Nearby_Stations']]  # Independent variable
y = bars_mv_reg['Is Outstanding']     # Dependent variable

# %%
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)

# %%
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.574374
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         Is Outstanding   No. Observations:                  523
# Model:                          Logit   Df Residuals:                      521
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 24 Mar 2024   Pseudo R-squ.:                0.008008
# Time:                        23:07:23   Log-Likelihood:                -300.40
# converged:                       True   LL-Null:                       -302.82
# Covariance Type:            nonrobust   LLR p-value:                   0.02765
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.8073      0.135      5.969      0.000       0.542       1.072
# Nearby_Stations     0.0170      0.008      2.141      0.032       0.001       0.033
# ===================================================================================

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('logistic_is_outstanding_all_stations_b.csv', 'w') as f:
    f.write(summary_as_csv)

# %%
X = restaurants_mv_reg[['Nearby_Stations']]  # Independent variable
y = restaurants_mv_reg['Is Outstanding']  # Dependent variable

# %%
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)

# %%
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.614678
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         Is Outstanding   No. Observations:                 2772
# Model:                          Logit   Df Residuals:                     2770
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 24 Mar 2024   Pseudo R-squ.:               0.0008510
# Time:                        23:09:44   Log-Likelihood:                -1703.9
# converged:                       True   LL-Null:                       -1705.3
# Covariance Type:            nonrobust   LLR p-value:                   0.08845
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.7752      0.050     15.620      0.000       0.678       0.872
# Nearby_Stations     0.0065      0.004      1.684      0.092      -0.001       0.014
# ===================================================================================

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('logistic_is_outstanding_all_stations_r.csv', 'w') as f:
    f.write(summary_as_csv)

# %% [markdown]
# ### Logistic Regression For Bars And Restaurants For All Rail

# %%
X = bars_and_restaurants_mv_reg[['Nearby_Rail_Stations']]  # Independent variable
y = bars_and_restaurants_mv_reg['Is Outstanding']     # Dependent variable

# %%
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)

# %%
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.590333
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         Is Outstanding   No. Observations:                 3191
# Model:                          Logit   Df Residuals:                     3189
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 24 Mar 2024   Pseudo R-squ.:               0.0001581
# Time:                        23:16:53   Log-Likelihood:                -1883.8
# converged:                       True   LL-Null:                       -1884.0
# Covariance Type:            nonrobust   LLR p-value:                    0.4402
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.9373      0.048    -19.727      0.000      -1.030      -0.844
# Nearby_Rail_Stations    -0.0078      0.010     -0.767      0.443      -0.028       0.012
# ========================================================================================

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('logistic_is_outstanding_all_rail_b_r.csv', 'w') as f:
    f.write(summary_as_csv)

# %%
X = bars_and_restaurants_mv_reg[['Nearby_Rail_Stations']]  # Independent variable
y = bars_and_restaurants_mv_reg['Exorbitant In Price']     # Dependent variable

# %%
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)

# %%
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.033249
#          Iterations 10
#                             Logit Regression Results
# ===============================================================================
# Dep. Variable:     Exorbitant In Price   No. Observations:                 3191
# Model:                           Logit   Df Residuals:                     3189
# Method:                            MLE   Df Model:                            1
# Date:                 Sun, 24 Mar 2024   Pseudo R-squ.:                 0.08766
# Time:                         23:18:05   Log-Likelihood:                -106.10
# converged:                        True   LL-Null:                       -116.29
# Covariance Type:             nonrobust   LLR p-value:                 6.322e-06
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -5.9298      0.351    -16.903      0.000      -6.617      -5.242
# Nearby_Rail_Stations     0.1683      0.033      5.061      0.000       0.103       0.233
# ========================================================================================

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('logistic_is_exorbitant_all_rail_b_r.csv', 'w') as f:
    f.write(summary_as_csv)

# %%
X = bars_mv_reg[['Nearby_Rail_Stations']]  # Independent variable
y = bars_mv_reg['Is Outstanding']     # Dependent variable

# %%
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)

# %%
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.575835
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         Is Outstanding   No. Observations:                  523
# Model:                          Logit   Df Residuals:                      521
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 24 Mar 2024   Pseudo R-squ.:                0.005484
# Time:                        23:19:10   Log-Likelihood:                -301.16
# converged:                       True   LL-Null:                       -302.82
# Covariance Type:            nonrobust   LLR p-value:                   0.06839
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.8738      0.125      6.996      0.000       0.629       1.119
# Nearby_Rail_Stations     0.0396      0.022      1.762      0.078      -0.004       0.084
# ========================================================================================

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('logistic_is_outstanding_all_rail_b.csv', 'w') as f:
    f.write(summary_as_csv)

# %%
X = restaurants_mv_reg[['Nearby_Rail_Stations']]  # Independent variable
y = restaurants_mv_reg['Is Outstanding']     # Dependent variable

# %%
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)

# %%
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.615201
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         Is Outstanding   No. Observations:                 2772
# Model:                          Logit   Df Residuals:                     2770
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 24 Mar 2024   Pseudo R-squ.:               6.589e-07
# Time:                        23:21:09   Log-Likelihood:                -1705.3
# converged:                       True   LL-Null:                       -1705.3
# Covariance Type:            nonrobust   LLR p-value:                    0.9622
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.8214      0.049     16.710      0.000       0.725       0.918
# Nearby_Rail_Stations     0.0005      0.011      0.047      0.962      -0.021       0.022
# ========================================================================================

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('logistic_is_outstanding_all_rail_r.csv', 'w') as f:
    f.write(summary_as_csv)

# %%
X = restaurants_mv_reg[['Nearby_Rail_Stations']]  # Independent variable
y = restaurants_mv_reg['Exorbitant In Price']     # Dependent variable

# %%
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)

# %%
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.036784
#          Iterations 10
#                             Logit Regression Results
# ===============================================================================
# Dep. Variable:     Exorbitant In Price   No. Observations:                 2772
# Model:                           Logit   Df Residuals:                     2770
# Method:                            MLE   Df Model:                            1
# Date:                 Sun, 24 Mar 2024   Pseudo R-squ.:                  0.1025
# Time:                         23:24:38   Log-Likelihood:                -101.97
# converged:                        True   LL-Null:                       -113.61
# Covariance Type:             nonrobust   LLR p-value:                 1.396e-06
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -5.8124      0.349    -16.640      0.000      -6.497      -5.128
# Nearby_Rail_Stations     0.1812      0.033      5.466      0.000       0.116       0.246
# ========================================================================================

# %%
summary = result.summary()
summary_as_csv = summary.as_csv()

with open('logistic_is_exorbitant_all_rail_r.csv', 'w') as f:
    f.write(summary_as_csv)
